# %%
import logging
import datetime
import json
import sys
from uuid import uuid4
from ffprobe import FFProbe

from google.cloud import speech_v1p1beta1 as speech
from google.cloud import storage
from google.oauth2 import service_account

# %%
def get_transcript(file_uri):
    storage_client = storage.Client()
    transcribe_client = speech.SpeechClient()

    audio = speech.RecognitionAudio(uri=file_uri)
    channel_count = 1

    config = speech.RecognitionConfig(
        encoding=speech.RecognitionConfig.AudioEncoding.LINEAR16,
        #sample_rate_hertz=sample_rate,
        audio_channel_count=channel_count,
        enable_separate_recognition_per_channel=False,
        enable_word_time_offsets=True,
        enable_word_confidence=True,
        enable_automatic_punctuation=True,
        language_code="en-US",
        diarization_config=speech.SpeakerDiarizationConfig(
            enable_speaker_diarization=True, min_speaker_count=1, max_speaker_count=10,
        ),
        model="latest_long",
        use_enhanced=True,
    )
    request = speech.LongRunningRecognizeRequest(config=config, audio=audio)
    operation = transcribe_client.long_running_recognize(request=request)

    response = operation.result()
    return response

# %%
file_uri = <gs url>
response = get_transcript(file_uri)
for result in response.results:
    print(result.alternatives[0].transcript)
# Out:
# Still outside Engine 5 with 95 and if I was 95 have a vehicle accident. I'm a real versus motorcycle.
#  It's gonna be at California and Ashby, California and Ashby time out 2048.

# %%
file_uri = <gs url>
response = get_transcript(file_uri)
for result in response.results:
    print(result.alternatives[0].transcript)
# Out:
# Hey 17 or something be advised. I got another caller stating that there's a male setting these fires. We're gonna invite these people.
#  something else

# %%
import IPython.display as ipd
ipd.Audio(<audio-file>)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
import matplotlib.pyplot as plt
import librosa.display
x, sr = librosa.load(<audio-file>)
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
# Out:
# E1110 20:14:15.719457574   26616 fork_posix.cc:70]           Fork support is only compatible with the epoll1 and poll polling strategies
# E1110 20:14:17.111190851   26616 fork_posix.cc:70]           Fork support is only compatible with the epoll1 and poll polling strategies
# E1110 20:14:17.147890813   26616 fork_posix.cc:70]           Fork support is only compatible with the epoll1 and poll polling strategies
# E1110 20:14:17.306050324   26616 fork_posix.cc:70]           Fork support is only compatible with the epoll1 and poll polling strategies
# E1110 20:14:17.320427789   26616 fork_posix.cc:70]           Fork support is only compatible with the epoll1 and poll polling strategies

# %%
ipd.Audio(<audio-file>)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x, sr = librosa.load(<audio-file>)
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')

# %%
file_uri = <gs-url>
response = get_transcript(file_uri)
for result in response.results:
    print(result.alternatives[0].transcript)
# Out:
# the man structure protecting group over command
#  17 I believe that Maple we can supply them if they can drop a three and Toes down to Maple.
#  All right. I copy that 17 from command.
#  And that you buy maple there just as if you dropping the three they can supply you often maple.
#  Yeah.

# %%
x, sr = librosa.load(<audio-file>)
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')

# %%
ipd.Audio(<audio-file>)
#FFProbe(<audio-file>).audio[0]
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
file_uri = "gs://citizen-production/r1/9079d6e7804a1268f87a9ca45250721d/US-MN-MSP/40F-11522-1663729440000.wav"
response = get_transcript(file_uri)
for result in response.results:
    print(result.alternatives[0].transcript)
# Out:
# Medic 17 724 Joseline Avenue East assault standby for police cross streets Greenbrier Street and Walsh Street Fox 616 on fire Ops 4 time 22:03 medic 17 724 Jessamine Avenue East assault stands by for police cross streets Greenbrier Street and Walsh Street Fox 616 on fire Ops 4 time 22:03.
